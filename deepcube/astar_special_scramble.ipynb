# %%
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams['figure.figsize'] = [15, 8]

# %%
resnet_steps = 32_508
normal_steps = 11_345

#print('Total attempts:', total_attempts)
plt.bar(0, normal_steps, 0.25, label="normal")
plt.bar(0.3, resnet_steps, 0.25, label="resnet")
ax = plt.gca()

ax.set_xticks([])
plt.ylabel("Number of steps")
plt.title("Number of steps taken to solve the scramble: F, U, R, U', R', F'")
plt.legend()
