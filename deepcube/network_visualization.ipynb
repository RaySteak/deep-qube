# %%
import sys
sys.path.append('../')

from torchview import draw_graph
from value_policy_net import ValuePolicyNet
from resnet_model import ResnetModel
import graphviz
graphviz.set_jupyter_format('png')
# Out:
# 'svg'

# %% [markdown]
# # Value Only Network

# %%
model_graph = draw_graph(ValuePolicyNet(True), input_size=(1, 20, 24), expand_nested=True)
model_graph.visual_graph

# %% [markdown]
# # Value and policy network

# %%
model_graph = draw_graph(ValuePolicyNet(), input_size=(1, 20, 24), expand_nested=True)
model_graph.visual_graph

# %% [markdown]
# # Resnet

# %%
model_graph = draw_graph(ResnetModel(20, 24, 5000, 1000, 4, 1, True), input_size=(1, 20, 24), expand_nested=True)
model_graph.resize_graph(4.0)
model_graph.visual_graph
