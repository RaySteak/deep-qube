# %%
import sys
sys.path.append('../')

from torchview import draw_graph

from q_network import QNetwork2DConv, QNetwork3DConv

import graphviz
graphviz.set_jupyter_format('png')
# Out:
# 'png'

# %% [markdown]
# # 2D Convolution Network

# %%
model_graph = draw_graph(QNetwork2DConv(), input_size=(1,6, 3, 3), expand_nested=True)
model_graph.resize_graph(4.0)
model_graph.visual_graph

# %% [markdown]
# # 3D Convolution Network

# %%
model_graph = draw_graph(QNetwork3DConv(), input_size=(1, 1, 6, 3, 3))
model_graph.resize_graph(3.0)
model_graph.visual_graph
